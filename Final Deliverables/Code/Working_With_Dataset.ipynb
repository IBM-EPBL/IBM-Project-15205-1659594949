# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/Global Super Store Dataset/Global_Superstore2.csv',encoding = 'unicode_escape')

# %%
df.head(10)
# Out:
#    Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0   32298   CA-2012-124891  31-07-2012  31-07-2012        Same Day
# 1   26341    IN-2013-77878  05-02-2013  07-02-2013    Second Class
# 2   25330    IN-2013-71249  17-10-2013  18-10-2013     First Class
# 3   13524  ES-2013-1579342  28-01-2013  30-01-2013     First Class
# 4   47221     SG-2013-4320  05-11-2013  06-11-2013        Same Day
# 5   22732    IN-2013-42360  28-06-2013  01-07-2013    Second Class
# 6   30570    IN-2011-81826  07-11-2011  09-11-2011     First Class
# 7   31192    IN-2012-86369  14-04-2012  18-04-2012  Standard Class
# 8   40155   CA-2014-135909  14-10-2014  21-10-2014  Standard Class
# 9   40936   CA-2012-116638  28-01-2012  31-01-2012    Second Class
#
#   Customer ID     Customer Name      Segment           City            State  \
# 0    RH-19495       Rick Hansen     Consumer  New York City         New York
# ...

# %%
df.tail(10)
# Out:
#        Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 51280   46582    TU-2014-6730  29-11-2014  30-11-2014     First Class
# 51281    6039  MX-2014-169530  09-06-2014  11-06-2014     First Class
# 51282    9922  MX-2012-100258  28-12-2012  31-12-2012     First Class
# 51283   24105   IN-2014-72327  30-05-2014  30-05-2014        Same Day
# 51284   24175   IN-2014-57662  05-08-2014  10-08-2014  Standard Class
# 51285   29002   IN-2014-62366  19-06-2014  19-06-2014        Same Day
# 51286   35398  US-2014-102288  20-06-2014  24-06-2014  Standard Class
# 51287   40470  US-2013-155768  02-12-2013  02-12-2013        Same Day
# 51288    9596  MX-2012-140767  18-02-2012  22-02-2012  Standard Class
# 51289    6147  MX-2012-134460  22-05-2012  26-05-2012    Second Class
#
#       Customer ID      Customer Name      Segment               City  \
# 51280     KF-6285     Karen Ferguson  Home Office             Midyat
# ...

# %%
print(df)
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891  31-07-2012  31-07-2012        Same Day
# 1       26341    IN-2013-77878  05-02-2013  07-02-2013    Second Class
# 2       25330    IN-2013-71249  17-10-2013  18-10-2013     First Class
# 3       13524  ES-2013-1579342  28-01-2013  30-01-2013     First Class
# 4       47221     SG-2013-4320  05-11-2013  06-11-2013        Same Day
# ...       ...              ...         ...         ...             ...
# 51285   29002    IN-2014-62366  19-06-2014  19-06-2014        Same Day
# 51286   35398   US-2014-102288  20-06-2014  24-06-2014  Standard Class
# 51287   40470   US-2013-155768  02-12-2013  02-12-2013        Same Day
# 51288    9596   MX-2012-140767  18-02-2012  22-02-2012  Standard Class
# 51289    6147   MX-2012-134460  22-05-2012  26-05-2012    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Length: 51290, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
# ...

# %%
df.dtypes
# Out:
# Row ID              int64
# Order ID           object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Customer ID        object
# Customer Name      object
# Segment            object
# City               object
# State              object
# Country            object
# Postal Code       float64
# Market             object
# Region             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# Shipping Cost     float64
# Order Priority     object
# dtype: object

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales      Quantity      Discount  \
# count  51290.00000   9994.000000  51290.000000  51290.000000  51290.000000
# mean   25645.50000  55190.379428    246.490581      3.476545      0.142908
# std    14806.29199  32063.693350    487.565361      2.278766      0.212280
# min        1.00000   1040.000000      0.444000      1.000000      0.000000
# 25%    12823.25000  23223.000000     30.758625      2.000000      0.000000
# 50%    25645.50000  56430.500000     85.053000      3.000000      0.000000
# 75%    38467.75000  90008.000000    251.053200      5.000000      0.200000
# max    51290.00000  99301.000000  22638.480000     14.000000      0.850000
#
#              Profit  Shipping Cost
# count  51290.000000   51290.000000
# mean      28.610982      26.375915
# std      174.340972      57.296804
# min    -6599.978000       0.000000
# 25%        0.000000       2.610000
# 50%        9.240000       7.790000
# 75%       36.810000      24.450000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
x=df.dropna(axis = 1)
x.head(10)
# Out:
#    Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0   32298   CA-2012-124891  31-07-2012  31-07-2012        Same Day
# 1   26341    IN-2013-77878  05-02-2013  07-02-2013    Second Class
# 2   25330    IN-2013-71249  17-10-2013  18-10-2013     First Class
# 3   13524  ES-2013-1579342  28-01-2013  30-01-2013     First Class
# 4   47221     SG-2013-4320  05-11-2013  06-11-2013        Same Day
# 5   22732    IN-2013-42360  28-06-2013  01-07-2013    Second Class
# 6   30570    IN-2011-81826  07-11-2011  09-11-2011     First Class
# 7   31192    IN-2012-86369  14-04-2012  18-04-2012  Standard Class
# 8   40155   CA-2014-135909  14-10-2014  21-10-2014  Standard Class
# 9   40936   CA-2012-116638  28-01-2012  31-01-2012    Second Class
#
#   Customer ID     Customer Name      Segment           City            State  \
# 0    RH-19495       Rick Hansen     Consumer  New York City         New York
# ...

# %%
cust_id = df['Customer ID']

# %%
print(cust_id)
# Out:
# 0        RH-19495
# 1        JR-16210
# 2        CR-12730
# 3        KM-16375
# 4         RH-9495
#            ...
# 51285    KE-16420
# 51286    ZC-21910
# 51287    LB-16795
# 51288    RB-19795
# 51289    MC-18100
# Name: Customer ID, Length: 51290, dtype: object

# %%
shipment_hist = df[['Order ID','Ship Mode','Customer ID','Customer Name','City','State','Product Name','Profit']]
shipment_hist
# Out:
#               Order ID       Ship Mode Customer ID     Customer Name  \
# 0       CA-2012-124891        Same Day    RH-19495       Rick Hansen
# 1        IN-2013-77878    Second Class    JR-16210     Justin Ritter
# 2        IN-2013-71249     First Class    CR-12730      Craig Reiter
# 3      ES-2013-1579342     First Class    KM-16375  Katherine Murray
# 4         SG-2013-4320        Same Day     RH-9495       Rick Hansen
# ...                ...             ...         ...               ...
# 51285    IN-2014-62366        Same Day    KE-16420   Katrina Edelman
# 51286   US-2014-102288  Standard Class    ZC-21910  Zuschuss Carroll
# 51287   US-2013-155768        Same Day    LB-16795    Laurel Beltran
# 51288   MX-2012-140767  Standard Class    RB-19795        Ross Baird
# 51289   MX-2012-134460    Second Class    MC-18100     Mick Crebagga
#
#                 City            State  \
# 0      New York City         New York
# 1         Wollongong  New South Wales
# ...

# %%
print(df[df['Category']=='Technology'])
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891  31-07-2012  31-07-2012        Same Day
# 2       25330    IN-2013-71249  17-10-2013  18-10-2013     First Class
# 3       13524  ES-2013-1579342  28-01-2013  30-01-2013     First Class
# 4       47221     SG-2013-4320  05-11-2013  06-11-2013        Same Day
# 5       22732    IN-2013-42360  28-06-2013  01-07-2013    Second Class
# ...       ...              ...         ...         ...             ...
# 51151   43296     PL-2011-5380  07-04-2011  09-04-2011    Second Class
# 51178   47992     SU-2014-3390  02-01-2014  06-01-2014  Standard Class
# 51219   35382   CA-2013-111913  05-08-2013  07-08-2013    Second Class
# 51237   31783   CA-2014-140963  11-06-2014  14-06-2014     First Class
# 51259   39396   CA-2013-169663  11-03-2013  14-03-2013     First Class
#
#       Customer ID     Customer Name      Segment           City  \
# ...

# %%
print(df[['Category','Ship Mode','Discount','Profit']])
# Out:
#               Category       Ship Mode  Discount    Profit
# 0           Technology        Same Day       0.0  762.1845
# 1            Furniture    Second Class       0.1 -288.7650
# 2           Technology     First Class       0.1  919.9710
# 3           Technology     First Class       0.1  -96.5400
# 4           Technology        Same Day       0.0  311.5200
# ...                ...             ...       ...       ...
# 51285  Office Supplies        Same Day       0.0    4.5000
# 51286  Office Supplies  Standard Class       0.8   -1.1100
# 51287  Office Supplies        Same Day       0.0   11.2308
# 51288  Office Supplies  Standard Class       0.0    2.4000
# 51289  Office Supplies    Second Class       0.0    1.8000
#
# [51290 rows x 4 columns]

# %%
print(df[df['Order Date']=='04-07-2011'])
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 2714    11911  IT-2011-2876489  04-07-2011  08-07-2011  Standard Class
# 9553    38029   CA-2011-120096  04-07-2011  07-07-2011     First Class
# 10821   27387    ID-2011-40953  04-07-2011  07-07-2011     First Class
# 14648   23183    IN-2011-47414  04-07-2011  10-07-2011  Standard Class
# 20781    8392   MX-2011-164574  04-07-2011  10-07-2011  Standard Class
# 27138   27385    ID-2011-40953  04-07-2011  07-07-2011     First Class
# 27302   38030   CA-2011-120096  04-07-2011  07-07-2011     First Class
# 27618   27386    ID-2011-40953  04-07-2011  07-07-2011     First Class
# 36331    3830   MX-2011-114615  04-07-2011  06-07-2011     First Class
# 42220   27384    ID-2011-40953  04-07-2011  07-07-2011     First Class
# 46126   38458   CA-2011-138709  04-07-2011  09-07-2011  Standard Class
# 47574   38459   CA-2011-138709  04-07-2011  09-07-2011  Standard Class
# ...
